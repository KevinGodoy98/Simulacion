# %% [markdown]
# ### Ejercicio en Clases
# Analizar y comprender, utilizando la estadistica descriptiva los datos de la fifa y de la prueba (datos del empleo dentro del Ecuador), además de implementar graficos que corroboren los resultado encontrados.
#
# Finalmente, agregar concluciones y recomedaciones al trabajo.

# %%
#importar las librerias necesarias
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import io
from google.colab import files
import plotly.graph_objects as go
from scipy import stats # importando scipy.stats

# %%
archivo_fifa = files.upload()
# Out:
#      <input type="file" id="files-7cbb41fe-58e2-40dc-8f4f-b66e8b855725" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7cbb41fe-58e2-40dc-8f4f-b66e8b855725">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving fifa_datos.csv to fifa_datos.csv

# %%
#Trabajar con otro tipo de datos Fifa
fifa = pd.read_csv(io.StringIO(archivo_fifa['fifa_datos.csv'].decode('utf-8')))
fifa.head(18207)
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
#Tomamos las columnas de interes en este caso -> jugador y peso
df = pd.DataFrame(fifa, columns = ['Name','Weight'])
df.head(18207)
# Out:
#                      Name  Weight
# 0                L. Messi   159.0
# 1       Cristiano Ronaldo   183.0
# 2               Neymar Jr   150.0
# 3                  De Gea   168.0
# 4            K. De Bruyne   154.0
# ...                   ...     ...
# 18202        J. Lundstram   134.0
# 18203  N. Christoffersson   170.0
# 18204           B. Worman   148.0
# 18205      D. Walker-Rice   154.0
# 18206           G. Nugent   176.0
#
# [18207 rows x 2 columns]

# %%
df = df.dropna()

# %%
# media arítmetica
df.mean() # Calcula la media aritmetica
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# Weight    165.979129
# dtype: float64

# %%
val=np.mean(fifa) # Mismo resultado desde la funcion de numpy
val
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3438: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# Unnamed: 0                    9103.000000
# ID                          214298.338606
# Age                             25.122206
# Overall                         66.238699
# Potential                       71.307299
# Special                       1597.809908
# International Reputation         1.113222
# Weak Foot                        2.947299
# Skill Moves                      2.361308
# Jersey Number                   19.546096
# Weight                         165.979129
# Crossing                        49.734181
# Finishing                       45.550911
# HeadingAccuracy                 52.298144
# ...

# %%
val.plot(kind="kde")
plt.title("Mince Pie Consumption Study Results")
plt.ylabel("Family Member")
plt.xlabel("Pies Consumed")
# Out:
# Text(0.5, 0, 'Pies Consumed')

# %%
fifa.mean(axis=1) # media aritmetica de cada fila
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# 0        3620.533333
# 1         572.844444
# 2        4347.533333
# 3        4366.244444
# 4        4400.511111
#             ...
# 18202    5777.022222
# 18203    5865.133333
# 18204    5835.066667
# 18205    5939.977778
# 18206    5944.888889
# Length: 18207, dtype: float64

# %%
fifa.mean(axis=0) # media aritmetica de cada columna
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Unnamed: 0                    9103.000000
# ID                          214298.338606
# Age                             25.122206
# Overall                         66.238699
# Potential                       71.307299
# Special                       1597.809908
# International Reputation         1.113222
# Weak Foot                        2.947299
# Skill Moves                      2.361308
# Jersey Number                   19.546096
# Weight                         165.979129
# Crossing                        49.734181
# Finishing                       45.550911
# HeadingAccuracy                 52.298144
# ShortPassing                    58.686712
# ...

# %%
mediana=fifa.median()
mediana
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Unnamed: 0                    9103.0
# ID                          221759.0
# Age                             25.0
# Overall                         66.0
# Potential                       71.0
# Special                       1635.0
# International Reputation         1.0
# Weak Foot                        3.0
# Skill Moves                      2.0
# Jersey Number                   17.0
# Weight                         165.0
# Crossing                        54.0
# Finishing                       49.0
# HeadingAccuracy                 56.0
# ShortPassing                    62.0
# Volleys                         44.0
# Dribbling                       61.0
# ...

# %%
mediana.plot(kind="kde")
plt.title("Mediana")
# Out:
# Text(0.5, 1.0, 'Mediana')

# %%
 # Desviación típica
desvia=np.std(fifa)
desvia
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3579: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# Unnamed: 0                   5255.908168
# ID                          29964.421288
# Age                             4.669814
# Overall                         6.908740
# Potential                       6.136327
# Special                       272.578530
# International Reputation        0.394020
# Weak Foot                       0.660438
# Skill Moves                     0.756143
# Jersey Number                  15.947326
# Weight                         15.592915
# Crossing                       18.364019
# Finishing                      19.525283
# HeadingAccuracy                17.379430
# ...

# %%
np.std(fifa, 0) # Desviación típica de cada columna
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3579: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# Unnamed: 0                   5255.908168
# ID                          29964.421288
# Age                             4.669814
# Overall                         6.908740
# Potential                       6.136327
# Special                       272.578530
# International Reputation        0.394020
# Weak Foot                       0.660438
# Skill Moves                     0.756143
# Jersey Number                  15.947326
# Weight                         15.592915
# Crossing                       18.364019
# Finishing                      19.525283
# HeadingAccuracy                17.379430
# ...

# %%
desvia.plot(kind="kde")
plt.title("desviacion")
# Out:
# Text(0.5, 1.0, 'desviacion')

# %%
# varianza
var=np.var(fifa) 
var
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3721: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return var(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# Unnamed: 0                  2.762457e+07
# ID                          8.978665e+08
# Age                         2.180717e+01
# Overall                     4.773069e+01
# Potential                   3.765451e+01
# Special                     7.429906e+04
# International Reputation    1.552517e-01
# Weak Foot                   4.361785e-01
# Skill Moves                 5.717526e-01
# Jersey Number               2.543172e+02
# Weight                      2.431390e+02
# Crossing                    3.372372e+02
# Finishing                   3.812367e+02
# HeadingAccuracy             3.020446e+02
# ...

# %%
var.plot(kind="kde")
plt.title("desviacion")
# Out:
# Text(0.5, 1.0, 'desviacion')

# %%
# moda
modas=stats.mode(df) # Calcula la moda de cada columna
# el 2do array devuelve la frecuencia.
modas
# Out:
# ModeResult(mode=array([['J. Rodríguez', 165.0]], dtype=object), count=array([[  11, 1483]]))

# %%
datos2 = np.array(df['Weight'])
stats.mode(datos2) # aqui la moda es el 6 porque aparece 5 veces en el vector.
# Out:
# ModeResult(mode=array([165.]), count=array([1483]))

# %%
# correlacion
np.corrcoef(datos2) # Crea matriz de correlación.
# Out:
# 1.0

# %%
# covarianza
np.cov(datos2) # calcula matriz de covarianza
# Out:
# array(243.15238957)

# %%
# resumen estadistadistico con pandas
fifa.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...

# %%
# sumando las columnas
fifa.sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# Unnamed: 0                                                          165738321
# ID                                                                 3901729851
# Name                        L. MessiCristiano RonaldoNeymar JrDe GeaK. De ...
# Age                                                                    457400
# Photo                       https://cdn.sofifa.org/players/4/19/158023.png...
# Nationality                 ArgentinaPortugalBrazilSpainBelgiumBelgiumCroa...
# Flag                        https://cdn.sofifa.org/flags/52.pnghttps://cdn...
# Overall                                                               1206008
# Potential                                                             1298292
# ...

# %%
# sumando filas
fifa.sum(axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# 0        162924.0
# 1         25778.0
# 2        195639.0
# 3        196481.0
# 4        198023.0
#            ...
# 18202    259966.0
# 18203    263931.0
# 18204    262578.0
# 18205    267299.0
# 18206    267520.0
# Length: 18207, dtype: float64

# %%
sumaFila=df.cumsum() # acumulados
sumaFila
# Out:
#                                                     Name     Weight
# 0                                               L. Messi      159.0
# 1                              L. MessiCristiano Ronaldo      342.0
# 2                     L. MessiCristiano RonaldoNeymar Jr      492.0
# 3               L. MessiCristiano RonaldoNeymar JrDe Gea      660.0
# 4      L. MessiCristiano RonaldoNeymar JrDe GeaK. De ...      814.0
# ...                                                  ...        ...
# 18202  L. MessiCristiano RonaldoNeymar JrDe GeaK. De ...  3013367.0
# 18203  L. MessiCristiano RonaldoNeymar JrDe GeaK. De ...  3013537.0
# 18204  L. MessiCristiano RonaldoNeymar JrDe GeaK. De ...  3013685.0
# 18205  L. MessiCristiano RonaldoNeymar JrDe GeaK. De ...  3013839.0
# 18206  L. MessiCristiano RonaldoNeymar JrDe GeaK. De ...  3014015.0
#
# [18159 rows x 2 columns]

# %%
sumaFila.plot(kind="kde")
plt.title("Suma de Filas")
# Out:
# Text(0.5, 1.0, 'Suma de Filas')

# %%
# media aritmetica de cada columna con pandas
fifa.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# Unnamed: 0                    9103.000000
# ID                          214298.338606
# Age                             25.122206
# Overall                         66.238699
# Potential                       71.307299
# Special                       1597.809908
# International Reputation         1.113222
# Weak Foot                        2.947299
# Skill Moves                      2.361308
# Jersey Number                   19.546096
# Weight                         165.979129
# Crossing                        49.734181
# Finishing                       45.550911
# HeadingAccuracy                 52.298144
# ShortPassing                    58.686712
# Volleys                         42.909026
# ...

# %%
# media aritmetica de cada fila con pandas
fifa.mean(axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# 0        3620.533333
# 1         572.844444
# 2        4347.533333
# 3        4366.244444
# 4        4400.511111
#             ...
# 18202    5777.022222
# 18203    5865.133333
# 18204    5835.066667
# 18205    5939.977778
# 18206    5944.888889
# Length: 18207, dtype: float64

# %% [markdown]
# #Empleo en ecuador

# %%
directorio6 = "/content/drive/MyDrive/datos.csv"
df = pd.read_csv(directorio6, sep=';', encoding='latin-1')
df
# Out:
#      Ranking \n(1) Tamaño  2021  Ranking \n(1) Tamaño  2020  \
# 0                             1                           1
# 1                             2                           2
# 2                             3                           3
# 3                             4                           5
# 4                             5                           4
# ..                          ...                         ...
# 297                         298                         283
# 298                         299                         285
# 299                         300                         294
# 300                         301                         301
# 301                         302                         302
#
#      Variación Ranking Tamaño 2020 - 2021 NUEVO\nGE  \
# 0                                       0       NaN
# 1                                       0       NaN
# 2                                       0       NaN
# ...

# %%
data=df.drop(['Unnamed: 40','Unnamed: 41','Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','Unnamed: 48','Unnamed: 49','Unnamed: 50','Unnamed: 51','Unnamed: 52','Unnamed: 53','Unnamed: 54','\nTotal Deuda Generada \n(9)'], axis=1)
data
# Out:
#      Ranking \n(1) Tamaño  2021  Ranking \n(1) Tamaño  2020  \
# 0                             1                           1
# 1                             2                           2
# 2                             3                           3
# 3                             4                           5
# 4                             5                           4
# ..                          ...                         ...
# 297                         298                         283
# 298                         299                         285
# 299                         300                         294
# 300                         301                         301
# 301                         302                         302
#
#      Variación Ranking Tamaño 2020 - 2021 NUEVO\nGE  \
# 0                                       0       NaN
# 1                                       0       NaN
# 2                                       0       NaN
# ...

# %%
data.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Ranking \n(1) Tamaño  2021                                                                                      151.500000
# Ranking \n(1) Tamaño  2020                                                                                      151.500000
# Variación Ranking Tamaño 2020 - 2021                                                                              0.000000
# No. de Integrantes domiciliados en PARAÍSOS FISCALES\n(**)                                                        1.506623
# No. de Integrantes y Empresas Offshore relacionadas con el Grupo Económico publicados en PANAMÁ PAPERS (***)      1.311258
# ...

# %%
val=np.mean(data) # Mismo resultado desde la funcion de numpy
val
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3438: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# Ranking \n(1) Tamaño  2021                                                                                      151.500000
# Ranking \n(1) Tamaño  2020                                                                                      151.500000
# Variación Ranking Tamaño 2020 - 2021                                                                              0.000000
# No. de Integrantes domiciliados en PARAÍSOS FISCALES\n(**)                                                        1.506623
# No. de Integrantes y Empresas Offshore relacionadas con el Grupo Económico publicados en PANAMÁ PAPERS (***)      1.311258
# ...

# %%
val.plot(kind="kde")
plt.title("media")
# Out:
# Text(0.5, 1.0, 'media')

# %%
meanfila=data.mean(axis=1) # media aritmetica de cada fila
meanfila
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# 0      23.500000
# 1      82.176471
# 2      33.666667
# 3      12.823529
# 4       9.666667
#          ...
# 297    76.066667
# 298    77.600000
# 299    70.333333
# 300    42.333333
# 301    66.266667
# Length: 302, dtype: float64

# %%
meanfila.plot(kind="kde")
plt.title("media segun la fila")
# Out:
# Text(0.5, 1.0, 'media segun la fila')

# %%
colummean=data.mean(axis=0) # media aritmetica de cada columna
colummean
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Ranking \n(1) Tamaño  2021                                                                                      151.500000
# Ranking \n(1) Tamaño  2020                                                                                      151.500000
# Variación Ranking Tamaño 2020 - 2021                                                                              0.000000
# No. de Integrantes domiciliados en PARAÍSOS FISCALES\n(**)                                                        1.506623
# No. de Integrantes y Empresas Offshore relacionadas con el Grupo Económico publicados en PANAMÁ PAPERS (***)      1.311258
# ...

# %%
colummean.plot(kind="kde")
plt.title("media segun la columna")
# Out:
# Text(0.5, 1.0, 'media segun la columna')

# %%
mediana=data.median()
mediana
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Ranking \n(1) Tamaño  2021                                                                                      151.5
# Ranking \n(1) Tamaño  2020                                                                                      151.5
# Variación Ranking Tamaño 2020 - 2021                                                                              1.0
# No. de Integrantes domiciliados en PARAÍSOS FISCALES\n(**)                                                        0.0
# No. de Integrantes y Empresas Offshore relacionadas con el Grupo Económico publicados en PANAMÁ PAPERS (***)      0.0
# ...

# %%
mediana.plot(kind="bar")
plt.title("Mediana")
# Out:
# Text(0.5, 1.0, 'Mediana')

# %%
 # Desviación típica
desvia=np.std(data)
desvia
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3579: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# Ranking \n(1) Tamaño  2021                                                                                      87.179413
# Ranking \n(1) Tamaño  2020                                                                                      87.179413
# Variación Ranking Tamaño 2020 - 2021                                                                            14.614925
# No. de Integrantes domiciliados en PARAÍSOS FISCALES\n(**)                                                       4.193770
# No. de Integrantes y Empresas Offshore relacionadas con el Grupo Económico publicados en PANAMÁ PAPERS (***)     4.548030
# ...

# %%
np.std(data, 0) # Desviación típica de cada columna
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3579: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# Ranking \n(1) Tamaño  2021                                                                                      87.179413
# Ranking \n(1) Tamaño  2020                                                                                      87.179413
# Variación Ranking Tamaño 2020 - 2021                                                                            14.614925
# No. de Integrantes domiciliados en PARAÍSOS FISCALES\n(**)                                                       4.193770
# No. de Integrantes y Empresas Offshore relacionadas con el Grupo Económico publicados en PANAMÁ PAPERS (***)     4.548030
# ...

# %%
desvia.plot(kind="bar")
plt.title("Desviacion")
# Out:
# Text(0.5, 1.0, 'Desviacion')

# %%
# varianza
var=np.var(data) 
var
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3721: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return var(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# Ranking \n(1) Tamaño  2021                                                                                      7600.250000
# Ranking \n(1) Tamaño  2020                                                                                      7600.250000
# Variación Ranking Tamaño 2020 - 2021                                                                             213.596026
# No. de Integrantes domiciliados en PARAÍSOS FISCALES\n(**)                                                        17.587704
# No. de Integrantes y Empresas Offshore relacionadas con el Grupo Económico publicados en PANAMÁ PAPERS (***)      20.684575
# ...

# %%
var.plot(kind="bar")
plt.title("Varianza")
# Out:
# Text(0.5, 1.0, 'Varianza')

# %%
# moda
modas=stats.mode(data) # Calcula la moda de cada columna
# el 2do array devuelve la frecuencia.
modas
# Out:
# ModeResult(mode=array([[1, 1, 1, 'X',
#         'COMPAÑÍA VERDU (CARILLI, CONSORCIO ENLACE SETECIENTOS OCHENTA, CONSORCIO VIAL MANABI, CORREDOR VIAL DE LA COSTA CVIALCO, CARGA, VEHICULOS Y TRANSPORTE, C.V. TRANSPORTE)',
#         'SI', 0, 0, 0, 0, 2, 0, 1, 1, 1, 1, 6.0, 1, 1, 3, '0',
#         '41.802.069', '0,00%', '0', '298.882.863', '1,89%', '-3,26%',
#         '-100,00%', '-0,56%', '0', '0', '0', '0', '341.024.099',
#         '70.798.058', '276.300.958', '791.999.072', '606.768', '517.653']],
#       dtype=object), count=array([[  1,   1,  20,  49,   1, 202, 213, 244,  88, 205,  17, 110,  90,
#         140,  27,  15,  16,   1,   1,   6,  17,   1,  19,   3,   1,   4,
#           2,  14,   6,   9,  55, 274, 274,   1,   1,   1,   1,   1,   1]]))

# %%
#sacamos todos los jugadores con el nombre del grupo economico
nombre= data[(data['Variación Ranking Tamaño 2020 - 2021'] == 17) & (data['\nTotal Recaudado (8) 2019'] ==  '3.579.801' )]
nombre
# Out:
#      Ranking \n(1) Tamaño  2021  Ranking \n(1) Tamaño  2020  \
# 141                         142                         159
#
#      Variación Ranking Tamaño 2020 - 2021 NUEVO\nGE  \
# 141                                    17       NaN
#
#                               \nNombre Grupo Económico  \
# 141  COMPAÑÍA VERDU (CARILLI, CONSORCIO ENLACE SETE...
#
#     Reporta sus BENEFICIARIOS EFECTIVOS \n(*)  \
# 141                                        SI
#
#      No. de Integrantes domiciliados en PARAÍSOS FISCALES\n(**)  \
# 141                                                  0
#
#      No. de Integrantes y Empresas Offshore relacionadas con el Grupo Económico publicados en PANAMÁ PAPERS (***)  \
# 141                                                  0
#
#      Personas \nNaturales (a)      Personas \nExtranjeras (b)      ...  \
# 141                             4                               0  ...
#
#      Impuesto Causado ISD 2020  Impuesto Causado ISD 2019  \
# ...

# %%
# correlacion
corre=data.corr() # Crea matriz de correlación.
corre
# Out:
#                                                     Ranking \n(1) Tamaño  2021  \
# Ranking \n(1) Tamaño  2021                                            1.000000
# Ranking \n(1) Tamaño  2020                                            0.985948
# Variación Ranking Tamaño 2020 - 2021                                 -0.083821
# No. de Integrantes domiciliados en PARAÍSOS FIS...                   -0.263394
# No. de Integrantes y Empresas Offshore relacion...                   -0.227357
# Personas \nNaturales (a)                                             -0.210834
# Personas \nExtranjeras (b)                                           -0.212226
# Sociedades \nNacionales (c)                                          -0.395249
# Sociedades \nExtranjeras (d)                                         -0.316657
# Contribuyentes\n Especiales                                          -0.415238
# Grandes \nContribuyentes e \nImportancia \nReca...                   -0.560233
# ...

# %%
# covarianza
data.cov() # calcula matriz de covarianza
# Out:
#                                                     Ranking \n(1) Tamaño  2021  \
# Ranking \n(1) Tamaño  2021                                         7625.500000
# Ranking \n(1) Tamaño  2020                                         7518.347176
# Variación Ranking Tamaño 2020 - 2021                               -107.152824
# No. de Integrantes domiciliados en PARAÍSOS FIS...                  -96.619601
# No. de Integrantes y Empresas Offshore relacion...                  -90.445183
# Personas \nNaturales (a)                                            -77.799003
# Personas \nExtranjeras (b)                                          -54.594684
# Sociedades \nNacionales (c)                                        -927.297342
# Sociedades \nExtranjeras (d)                                       -316.239203
# Contribuyentes\n Especiales                                        -185.702658
# Grandes \nContribuyentes e \nImportancia \nReca...                  -82.795681
# ...

# %%
# resumen estadistadistico con pandas
data.describe()
# Out:
#        Ranking \n(1) Tamaño  2021  Ranking \n(1) Tamaño  2020  \
# count                  302.000000                  302.000000
# mean                   151.500000                  151.500000
# std                     87.324109                   87.324109
# min                      1.000000                    1.000000
# 25%                     76.250000                   76.250000
# 50%                    151.500000                  151.500000
# 75%                    226.750000                  226.750000
# max                    302.000000                  302.000000
#
#        Variación Ranking Tamaño 2020 - 2021  \
# count                            302.000000
# mean                               0.000000
# std                               14.639182
# min                              -85.000000
# 25%                               -5.750000
# 50%                                1.000000
# 75%                                7.750000
# max                               49.000000
#
# ...

# %%
# sumando las columnas
data.sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# Ranking \n(1) Tamaño  2021                                                                                                                                  45753
# Ranking \n(1) Tamaño  2020                                                                                                                                  45753
# Variación Ranking Tamaño 2020 - 2021                                                                                                                            0
# \nNombre Grupo Económico                                                                                        BANCO PICHINCHA (DINERS CLUB DEL ECUADOR, BANC...
# ...

# %%
# sumando filas
data.sum(axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# 0       376.0
# 1      1397.0
# 2       505.0
# 3       218.0
# 4       145.0
#         ...
# 297    1141.0
# 298    1164.0
# 299    1055.0
# 300     635.0
# 301     994.0
# Length: 302, dtype: float64

# %%
sumaFila=data['Variación Ranking Tamaño 2020 - 2021'].cumsum() # acumulados
sumaFila
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 297    20
# 298     6
# 299     0
# 300     0
# 301     0
# Name: Variación Ranking Tamaño 2020 - 2021, Length: 302, dtype: int64

# %%
sumaFila.plot(kind="kde")
plt.title("suma acumulada")
# Out:
# Text(0.5, 1.0, 'suma acumulada')
