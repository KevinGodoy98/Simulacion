# %%
# <p>Se tiene 2 dados al lanzarlos y sumo las caras en un rango de 2 a 12
# Generar 2 numeros pseudo aleatorias y se suma las caras lo iteramos en 100,1000,10000 y
# mostrar en una barra de histogramas el valor que mas se repite</p>
import random
from statistics import mode
import matplotlib.pyplot as plot


def cien():
    sumas = []
    for i in range(0, 100):
        #print('-----------------iteracion:', i, '-----------------')
        dadoA = random.randint(1, 6)
        #print('Dado A:', dadoA)
        dadoB = random.randint(1, 6)
        #print('Dado B:', dadoB)
        suma = int(dadoA) + int(dadoB)
        sumas.append(suma)
        #print('el resultado es:', suma)

    print('los valores de las sumas son :', sumas)
    valor_mas_repetido = mode(sumas)
    print('El valor mas repetido es:',valor_mas_repetido )
    plot.hist(x=sumas , bins=valor_mas_repetido , color='#F2AB6D',rwidth=0.85 )
    plot.title('Histograma con 100 interaciones')
    plot.xlabel('Valores')
    plot.ylabel('Frecuencia')
    plot.show()

# %%
cien()
# Out:
# los valores de las sumas son : [7, 6, 9, 5, 6, 8, 8, 6, 8, 6, 7, 9, 6, 6, 7, 6, 3, 10, 11, 7, 9, 9, 8, 8, 3, 7, 8, 10, 11, 9, 7, 9, 6, 7, 6, 7, 6, 10, 5, 5, 12, 11, 11, 3, 7, 4, 5, 7, 8, 8, 6, 5, 8, 4, 8, 3, 10, 6, 10, 8, 9, 6, 11, 10, 8, 9, 2, 7, 8, 6, 4, 7, 7, 6, 9, 9, 9, 10, 8, 5, 6, 10, 7, 5, 10, 6, 9, 7, 9, 8, 8, 11, 6, 6, 10, 9, 8, 11, 6, 7]
# El valor mas repetido es: 6

# %%
def mil():
    sumas = []
    for i in range(0, 1000):
        #print('-----------------iteracion:', i, '-----------------')
        dadoA = random.randint(1, 6)
        # print('Dado A:', dadoA)
        dadoB = random.randint(1, 6)
        # print('Dado B:', dadoB)
        suma = int(dadoA) + int(dadoB)
        sumas.append(suma)
        # print('el resultado es:', suma)

    print('los valores de las sumas son :', sumas)
    valor_mas_repetido = mode(sumas)
    print('El valor mas repetido es:', valor_mas_repetido)
    plot.hist(x=sumas, bins=valor_mas_repetido, color='#F2AB6D', rwidth=0.85)
    plot.title('Histograma con 100 interaciones')
    plot.xlabel('Valores')
    plot.ylabel('Frecuencia')
    plot.show()

# %%
mil()
# Out:
# los valores de las sumas son : [12, 9, 10, 4, 7, 6, 7, 7, 7, 5, 9, 5, 7, 5, 9, 7, 5, 3, 9, 6, 10, 8, 6, 8, 2, 8, 12, 6, 6, 3, 7, 9, 4, 9, 6, 8, 2, 8, 8, 9, 3, 10, 5, 5, 9, 9, 4, 6, 5, 10, 6, 9, 8, 5, 12, 7, 7, 2, 5, 10, 3, 4, 4, 4, 6, 5, 10, 12, 4, 6, 8, 8, 4, 5, 5, 8, 5, 8, 4, 12, 7, 4, 6, 7, 4, 6, 7, 7, 6, 7, 8, 10, 7, 5, 9, 3, 8, 11, 4, 8, 4, 5, 8, 4, 9, 12, 10, 10, 10, 6, 5, 9, 9, 2, 8, 6, 6, 8, 9, 7, 4, 11, 7, 8, 8, 8, 8, 7, 5, 5, 10, 10, 4, 9, 10, 4, 5, 8, 4, 6, 4, 8, 8, 8, 6, 5, 6, 5, 8, 4, 8, 7, 3, 8, 12, 4, 5, 7, 8, 3, 2, 11, 7, 5, 5, 7, 3, 10, 7, 7, 4, 7, 5, 4, 7, 8, 8, 7, 9, 7, 11, 6, 10, 3, 7, 8, 3, 7, 4, 4, 2, 7, 5, 9, 2, 6, 6, 7, 12, 4, 6, 5, 4, 2, 4, 7, 5, 9, 6, 11, 7, 3, 7, 7, 4, 4, 10, 10, 7, 3, 6, 3, 6, 10, 5, 2, 7, 3, 4, 8, 2, 2, 8, 7, 9, 7, 9, 8, 5, 8, 6, 9, 6, 6, 8, 8, 9, 8, 7, 4, 8, 2, 8, 7, 9, 10, 7, 10, 12, 11, 9, 5, 7, 5, 4, 10, 6, 10, 11, 10, 7, 4, 6, 7, 9, 10, 7, 10, 3, 7, 5, 6, 10, 9, 7, 6, 5, 7, 6, 11, 7, 10, 7, 4, 4, 11, 10, 6, 7, 4, 2, 4, 7, 10, 9, 9, 9
# ...

# %%
def diezmil():
    sumas = []
    for i in range(0, 10000):
        #print('-----------------iteracion:', i, '-----------------')
        dadoA = random.randint(1, 6)
        # print('Dado A:', dadoA)
        dadoB = random.randint(1, 6)
        # print('Dado B:', dadoB)
        suma = int(dadoA) + int(dadoB)
        sumas.append(suma)
        # print('el resultado es:', suma)

    print('los valores de las sumas son :', sumas)
    valor_mas_repetido = mode(sumas)
    print('El valor mas repetido es:', valor_mas_repetido)
    plot.hist(x=sumas, bins=valor_mas_repetido, color='#F2AB6D', rwidth=0.85)
    plot.title('Histograma con 100 interaciones')
    plot.xlabel('Valores')
    plot.ylabel('Frecuencia')
    plot.show()

# %%
diezmil()
# Out:
# los valores de las sumas son : [9, 3, 7, 6, 7, 3, 11, 6, 10, 3, 4, 5, 12, 7, 11, 5, 5, 10, 9, 5, 11, 11, 7, 9, 9, 9, 5, 12, 6, 8, 9, 5, 9, 8, 5, 9, 9, 4, 3, 9, 3, 4, 6, 10, 7, 6, 7, 6, 11, 8, 5, 9, 10, 4, 9, 5, 9, 5, 8, 6, 9, 9, 10, 2, 8, 7, 10, 5, 9, 7, 8, 7, 10, 7, 11, 8, 6, 7, 5, 10, 7, 8, 3, 6, 9, 9, 11, 6, 8, 2, 4, 5, 10, 8, 4, 9, 8, 6, 5, 8, 5, 6, 11, 6, 8, 6, 12, 11, 6, 10, 7, 9, 9, 4, 9, 5, 10, 12, 11, 3, 7, 8, 7, 3, 10, 6, 6, 12, 8, 7, 7, 6, 5, 6, 3, 9, 8, 9, 4, 10, 5, 5, 3, 7, 8, 5, 8, 6, 7, 12, 6, 10, 6, 6, 6, 3, 6, 5, 11, 9, 2, 6, 5, 6, 7, 10, 6, 4, 8, 8, 6, 7, 8, 7, 2, 8, 4, 5, 12, 6, 8, 11, 12, 7, 4, 6, 8, 3, 8, 8, 5, 11, 6, 4, 6, 6, 9, 10, 12, 3, 4, 7, 7, 10, 7, 4, 6, 7, 9, 8, 11, 9, 8, 6, 4, 7, 5, 9, 8, 7, 7, 4, 6, 11, 10, 11, 5, 7, 9, 5, 7, 11, 5, 4, 6, 10, 6, 9, 5, 8, 7, 12, 7, 7, 4, 11, 7, 5, 9, 6, 4, 3, 8, 8, 6, 6, 4, 6, 5, 3, 5, 9, 4, 5, 4, 4, 3, 9, 8, 7, 11, 11, 5, 10, 4, 5, 7, 9, 3, 6, 9, 10, 3, 5, 5, 7, 6, 9, 11, 7, 5, 2, 8, 10, 8, 7, 9, 7, 5, 7, 9, 9, 6, 7, 8
# ...
